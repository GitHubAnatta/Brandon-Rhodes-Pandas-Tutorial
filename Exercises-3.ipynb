# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
titles = pd.read_csv('data/titles.csv', index_col=None)
titles.head()
# Out:
#                   title  year
# 0           Burgtheater  1936
# 1  Main Hoon Angrakshak  2003
# 2        Faded Memories  2008
# 3            Cinema Six  2012
# 4      I Want Your Love  2012

# %%
cast = pd.read_csv('data/cast.csv', index_col=None)
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### Using groupby(), plot the number of films that have been released each decade in the history of cinema.

# %%
titles[titles.year < 2020].groupby(titles.year // 10 * 10).year.size().plot()

# %% [markdown]
# ### Use groupby() to plot the number of "Hamlet" films made each decade.

# %%
titles[(titles.year < 2020) & (titles.title == 'Hamlet')].groupby(titles.year // 10 * 10).year.size().plot()

# %% [markdown]
# ### How many leading (n=1) roles were available to actors, and how many to actresses, in each year of the 1950s?

# %%
cast[(cast.year // 10 == 195) & cast.n == 1].groupby(['year', 'type']).size()
# Out:
# year  type
# 1950  actor      7649
#       actress    3204
# 1951  actor      8053
#       actress    3396
# 1952  actor      7681
#       actress    3344
# 1953  actor      8129
#       actress    3582
# 1954  actor      7792
#       actress    3487
# 1955  actor      8046
#       actress    3436
# 1956  actor      8329
#       actress    3689
# 1957  actor      8905
#       actress    3907
# 1958  actor      8978
#       actress    3823
# 1959  actor      8517
#       actress    3926
# dtype: int64

# %% [markdown]
# ### In the 1950s decade taken as a whole, how many total roles were available to actors, and how many to actresses, for each "n" number 1 through 5?

# %%
cast[(cast.year // 10 == 195) & (cast.n <= 5)].groupby(['n','type']).size()
# Out:
# n    type
# 1.0  actor      6692
#      actress    3040
# 2.0  actor      4640
#      actress    4635
# 3.0  actor      5654
#      actress    3201
# 4.0  actor      5663
#      actress    2881
# 5.0  actor      5674
#      actress    2592
# dtype: int64

# %% [markdown]
# ### Use groupby() to determine how many roles are listed for each of the Pink Panther movies.

# %%
cast[cast.title.str.endswith('Pink Panther')]
# Out:
#                                   title  year                    name  \
# 1010                   The Pink Panther  2006          William Abadie
# 2100        Revenge of the Pink Panther  1978          Fredric Abbott
# 4921          Curse of the Pink Panther  1983           William Abney
# 13007           Son of the Pink Panther  1993              Tony Adams
# 13008    The Return of the Pink Panther  1975              Tony Adams
# 14470    The Return of the Pink Panther  1975             Yashaw Adem
# 15078                  The Pink Panther  2006       Scott (II) Adkins
# 34701       Revenge of the Pink Panther  1978         Lewis Alexander
# 40517       Revenge of the Pink Panther  1978             Irvin Allen
# 57923                  The Pink Panther  2006  Patrick (III) Anderson
# 69064       Revenge of the Pink Panther  1978             Paul Antrim
# 81803         Curse of the Pink Panther  1983              Peter Arne
# ...

# %%
cast[cast.title.str.endswith( 'Pink Panther')].groupby(['year']).size()
# Out:
# year
# 1963    21
# 1975    30
# 1978    68
# 1982    41
# 1983    67
# 1993    46
# 2006    90
# dtype: int64

# %% [markdown]
# ### List, in order by year, each of the films in which Frank Oz has played more than 1 role.

# %%
frank_oz = cast[cast.name == 'Frank Oz'].groupby(['year','title']).size()
frank_oz
# Out:
# year  title
# 1979  The Muppet Movie                                  8
# 1980  Star Wars: Episode V - The Empire Strikes Back    1
#       The Blues Brothers                                1
# 1981  An American Werewolf in London                    2
#       The Great Muppet Caper                            6
# 1982  The Dark Crystal                                  2
# 1983  Star Wars: Episode VI - Return of the Jedi        1
#       Superman III                                      1
#       Trading Places                                    1
# 1984  The Muppets Take Manhattan                        7
# 1985  Follow That Bird                                  3
#       Spies Like Us                                     1
# 1986  Labyrinth                                         1
# 1992  Innocent Blood                                    1
#       The Muppet Christmas Carol                        7
# 1996  Muppet Treasure Island                            4
# ...

# %%
frank_oz[frank_oz > 1]
# Out:
# year  title
# 1979  The Muppet Movie                        8
# 1981  An American Werewolf in London          2
#       The Great Muppet Caper                  6
# 1982  The Dark Crystal                        2
# 1984  The Muppets Take Manhattan              7
# 1985  Follow That Bird                        3
# 1992  The Muppet Christmas Carol              7
# 1996  Muppet Treasure Island                  4
# 1999  Muppets from Space                      4
#       The Adventures of Elmo in Grouchland    3
# dtype: int64

# %% [markdown]
# ### List each of the characters that Frank Oz has portrayed at least twice.

# %%
frank_oz_characters = cast[cast.name == 'Frank Oz'].groupby(['character']).size()
frank_oz_characters
# Out:
# character
# Animal                                                  6
# Aughra, a Keeper Of Secrets (performer)                 1
# Bert                                                    3
# Brain Surgeon                                           1
# Chamberlain (performer)                                 1
# Cookie Monster                                          5
# Corrections Officer                                     1
# Corrupt Cop                                             1
# Doc Hopper's Men                                        1
# Fozzie                                                  1
# Fozzie Bear                                             4
# Fozzie Bear as Fozziewig                                1
# Fungus                                                  1
# George the Janitor                                      1
# Gramps                                                  1
# Grover                                                  2
# ...

# %%
frank_oz_characters[frank_oz_characters > 1]
# Out:
# character
# Animal            6
# Bert              3
# Cookie Monster    5
# Fozzie Bear       4
# Grover            2
# Miss Piggy        6
# Sam the Eagle     5
# Yoda              6
# dtype: int64
